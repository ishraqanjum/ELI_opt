# %%
import copy
import math
import numpy as np

'''
    Pure Python/Numpy implementation of the Nelder-Mead algorithm.
    Reference: https://en.wikipedia.org/wiki/Nelder%E2%80%93Mead_method
'''

def nelder_meadus(f, x_start, bounds,
                step=0.1, no_improve_thr=1e-3,
                no_improv_break=10, max_iter=500,
                alpha=1., gamma=2., rho=-0.5, sigma=0.5):
    '''
        @param f (function): function to optimize, must return a scalar score
            and operate over a numpy array of the same dimensions as x_start
        @param x_start (numpy array): initial position
        @param bounds (list): 3-dimensional bound for each parameter, as a list of 3 tuples
        @param step (float): look-around radius in initial step
        @no_improv_thr,  no_improv_break (float, int): break after no_improv_break iterations with
            an improvement lower than no_improv_thr
        @max_iter (int): always break after this number of iterations.
            Set it to 0 to loop indefinitely.
        @alpha, gamma, rho, sigma (floats): parameters of the algorithm
            (see Wikipedia page for reference)
        return: tuple (best parameter array, best score)
    '''

    # init
    dim = len(x_start)
    prev_best = f(x_start)
    no_improv = 0
    res = [[x_start, prev_best]]

    for i in range(dim):
        x = copy.copy(x_start)
        x[i] = x[i] + step
        x = np.clip(x, bounds[i][0], bounds[i][1])
        score = f(x)
        res.append([x, score])

    # simplex iter
    iters = 0
    fev = 1
    while 1:
        # order
        res.sort(key=lambda x: x[1])
        best = res[0][1]

        # break after max_iter
        if max_iter and iters >= max_iter:
#             return np.clip(res[0][0], bounds[0][0], bounds[0][1]), res[0][1]
              return res[0], iters, fev
#         iters += 1

        # break after no_improv_break iterations with no improvement
        print('...best so far:', best)
        print('function evaluations:', fev)

#         if best < prev_best - no_improve_thr:
#             no_improv = 0
#             prev_best = best
#         else:
#             no_improv += 1

#         if no_improv >= no_improv_break:
#             return np.clip(res[0][0], bounds[0][0], bounds[0][1]), res[0][1]
        
        
        iters += 1

        # centroid
        x0 = [0.] * dim
        for tup in res[:-1]:
            for i, c in enumerate(tup[0]):
                x0[i] += c / (len(res)-1)

        

                    # reflection
        xr = x0 + alpha*(x0 - res[-1][0])
        rscore = f(xr)
        fev += 1
        if res[0][1] <= rscore < res[-2][1]:
            del res[-1]
            res.append([xr, rscore])
            continue

        # expansion
        if rscore < res[0][1]:
            xe = x0 + gamma*(x0 - res[-1][0])
            escore = f(xe)
            fev += 1
            if escore < rscore:
                del res[-1]
                res.append([xe, escore])
                continue
            else:
                del res[-1]
                res.append([xr, rscore])
                continue

        # contraction
        xc = x0 + rho*(x0 - res[-1][0])
        cscore = f(xc)
        fev += 1
        if cscore < res[-1][1]:
            del res[-1]
            res.append([xc, cscore])
            continue

        # reduction
        x1 = res[0][0]
        nres = []
        for tup in res:
            redx = x1 + sigma*(tup[0] - x1)
            score = f(redx)
            fev += 1
            nres.append([redx, score])
        res = nres

        # check if the result is within the bounds
        for i in range(len(res)):
            for j in range(len(x_start)):
                if res[i][0][j] < bounds[j][0]:
                    res[i][0][j] = bounds[j][0]
                elif res[i][0][j] > bounds[j][1]:
                    res[i][0][j] = bounds[j][1]

#         # stopping criterion
#         if rscore < 1e-6:
#             return res[0], iters, fev
#         print(fev)
        return res[0], iters, fev

# %%
import math
import numpy as np

# Define the function to optimize
def f(x):
    return math.sin(x[0]) * math.cos(x[1]) * (1. / (abs(x[2]) + 1))

# Define the initial position and bounds
x_start = np.array([0., 0., 0.])
bounds = [(0, 10), (-5, 5), (-1, 1)]

# Run the optimization using Nelder-Mead method
best_score, iters, fev = nelder_meadus(f, x_start, bounds=bounds)
# nelder_meadus(f, x_start, bounds=bounds)

# Print the results
# print("Best parameters:", best_param)
print("Best score:", best_score)
print("Iterations:", iters)
print("Function evaluations:", fev)
# Out:
# ...best so far: 0.0
# function evaluations: 1
# ...best so far: -0.17970619241280353
# function evaluations: 3
# ...best so far: -0.17970619241280353
# function evaluations: 4
# ...best so far: -0.30657463012029224
# function evaluations: 6
# ...best so far: -0.5263352673542919
# function evaluations: 8
# ...best so far: -0.5263352673542919
# function evaluations: 9
# ...best so far: -0.7526372727014512
# function evaluations: 11
# ...best so far: -0.7526372727014512
# function evaluations: 12
# ...best so far: -0.7526372727014512
# function evaluations: 13
# ...best so far: -0.7526372727014512
# function evaluations: 15
# ...best so far: -0.7526372727014512
# function evaluations: 17
# ...best so far: -0.8877444448223267
# function evaluations: 19
# ...best so far: -0.8877444448223267
# function evaluations: 20
# ...best so far: -0.8877444448223267
# function evaluations: 21
# ...best so far: -0.8877444448223267
# function evaluations: 23
# ...best so far: -0.9039290159484077
# function evaluations: 25
# ...best so far: -0.9053729782222878
# function evaluations: 27
# ...best so far: -0.9095077910015297
# function evaluations: 29
# ...best so far: -0.9399983100658024
# function evaluations: 31
# ...best so far: -0.9399983100658024
# function evaluations: 33
# ...best so far: -0.9399983100658024
# function evaluations: 35
# ...best so far: -0.9475659934272104
# function evaluations: 37
# ...best so far: -0.9562352749304285
# function evaluations: 39
# ...best so far: -0.9711268379185659
# function evaluations: 41
# ...best so far: -0.9732024507834273
# function evaluations: 43
# ...best so far: -0.9732024507834273
# function evaluations: 44
# ...best so far: -0.9944200394377077
# function evaluations: 46
# ...best so far: -0.9944200394377077
# function evaluations: 47
# ...best so far: -0.9944200394377077
# function evaluations: 48
# ...best so far: -0.9944200394377077
# function evaluations: 49
# ...best so far: -0.9944200394377077
# function evaluations: 50
# ...best so far: -0.9944200394377077
# function evaluations: 52
# ...best so far: -0.9944200394377077
# function evaluations: 54
# ...best so far: -0.9944200394377077
# function evaluations: 56
# ...best so far: -0.9944200394377077
# function evaluations: 57
# ...best so far: -0.9944200394377077
# function evaluations: 58
# ...best so far: -0.9958458477321551
# function evaluations: 60
# ...best so far: -0.9958458477321551
# function evaluations: 61
# ...best so far: -0.9979552555365486
# function evaluations: 63
# ...best so far: -0.9979552555365486
# function evaluations: 65
# ...best so far: -0.9979552555365486
# function evaluations: 67
# ...best so far: -0.998372455504012
# function evaluations: 69
# ...best so far: -0.998525029521357
# function evaluations: 71
# ...best so far: -0.9989501462989028
# function evaluations: 73
# ...best so far: -0.9991383119813444
# function evaluations: 75
# ...best so far: -0.9995321167241182
# function evaluations: 77
# ...best so far: -0.9995991389547175
# function evaluations: 79
# ...best so far: -0.9995991389547175
# function evaluations: 80
# ...best so far: -0.9997342347691284
# function evaluations: 82
# ...best so far: -0.9997342347691284
# function evaluations: 84
# ...best so far: -0.9997356713307467
# function evaluations: 86
# ...best so far: -0.9997587541867651
# function evaluations: 88
# ...best so far: -0.9998149379158637
# function evaluations: 90
# ...best so far: -0.9998780473036525
# function evaluations: 92
# ...best so far: -0.9998780473036525
# function evaluations: 94
# ...best so far: -0.999879662598868
# function evaluations: 96
# ...best so far: -0.999891411453953
# function evaluations: 98
# ...best so far: -0.999917441356253
# function evaluations: 100
# ...best so far: -0.999917441356253
# function evaluations: 102
# ...best so far: -0.999922177051292
# function evaluations: 104
# ...best so far: -0.9999234182033051
# function evaluations: 106
# ...best so far: -0.9999368545748725
# function evaluations: 108
# ...best so far: -0.9999368545748725
# function evaluations: 110
# ...best so far: -0.9999386780894587
# function evaluations: 112
# ...best so far: -0.9999386780894587
# function evaluations: 114
# ...best so far: -0.9999406374646704
# function evaluations: 116
# ...best so far: -0.9999428069377192
# function evaluations: 118
# ...best so far: -0.9999428069377192
# function evaluations: 120
# ...best so far: -0.9999435147670585
# function evaluations: 122
# ...best so far: -0.9999440538269682
# function evaluations: 124
# ...best so far: -0.9999447019836769
# function evaluations: 126
# ...best so far: -0.9999447346002792
# function evaluations: 128
# ...best so far: -0.9999453499355355
# function evaluations: 130
# ...best so far: -0.9999453499355355
# function evaluations: 132
# ...best so far: -0.9999457620319515
# function evaluations: 134
# ...best so far: -0.9999457620319515
# function evaluations: 136
# ...best so far: -0.9999458515647731
# function evaluations: 138
# ...best so far: -0.9999458515647731
# function evaluations: 139
# ...best so far: -0.9999465563065794
# function evaluations: 141
# ...best so far: -0.9999465563065794
# function evaluations: 143
# ...best so far: -0.9999465563065794
# function evaluations: 145
# ...best so far: -0.9999465563065794
# function evaluations: 146
# ...best so far: -0.9999465563065794
# function evaluations: 148
# ...best so far: -0.9999471285905395
# function evaluations: 150
# ...best so far: -0.9999471285905395
# function evaluations: 151
# ...best so far: -0.9999474579344637
# function evaluations: 153
# ...best so far: -0.9999474579344637
# function evaluations: 154
# ...best so far: -0.9999483638280067
# function evaluations: 156
# ...best so far: -0.9999483638280067
# function evaluations: 157
# ...best so far: -0.9999499121918586
# function evaluations: 159
# ...best so far: -0.9999516180297975
# function evaluations: 161
# ...best so far: -0.9999516180297975
# function evaluations: 162
# ...best so far: -0.9999556938849247
# function evaluations: 164
# ...best so far: -0.9999584810730168
# function evaluations: 166
# ...best so far: -0.9999584810730168
# function evaluations: 167
# ...best so far: -0.9999666077979849
# function evaluations: 169
# ...best so far: -0.9999666077979849
# function evaluations: 170
# ...best so far: -0.9999695452312247
# function evaluations: 172
# ...best so far: -0.9999708054542021
# function evaluations: 174
# ...best so far: -0.9999708054542021
# function evaluations: 175
# ...best so far: -0.9999708054542021
# function evaluations: 177
# ...best so far: -0.9999710490755804
# function evaluations: 179
# ...best so far: -0.9999710490755804
# function evaluations: 181
# ...best so far: -0.9999710490755804
# function evaluations: 183
# ...best so far: -0.9999716516710552
# function evaluations: 185
# ...best so far: -0.9999716516710552
# function evaluations: 186
# ...best so far: -0.9999716516710552
# function evaluations: 187
# ...best so far: -0.99997234077344
# function evaluations: 189
# ...best so far: -0.99997234077344
# function evaluations: 190
# ...best so far: -0.99997234077344
# function evaluations: 191
# ...best so far: -0.9999729750797497
# function evaluations: 193
# ...best so far: -0.9999742181713005
# function evaluations: 195
# ...best so far: -0.9999750098369345
# function evaluations: 197
# ...best so far: -0.9999768344777011
# function evaluations: 199
# ...best so far: -0.9999801078881932
# function evaluations: 201
# ...best so far: -0.9999830812616495
# function evaluations: 203
# ...best so far: -0.9999873054820574
# function evaluations: 205
# ...best so far: -0.9999879270700839
# function evaluations: 207
# ...best so far: -0.9999899026604628
# function evaluations: 209
# ...best so far: -0.9999911329988747
# function evaluations: 211
# ...best so far: -0.9999911329988747
# function evaluations: 212
# ...best so far: -0.9999911329988747
# function evaluations: 214
# ...best so far: -0.9999911329988747
# function evaluations: 216
# ...best so far: -0.9999920633680124
# function evaluations: 218
# ...best so far: -0.9999920633680124
# function evaluations: 219
# ...best so far: -0.9999921414600365
# function evaluations: 221
# ...best so far: -0.9999921414600365
# function evaluations: 223
# ...best so far: -0.9999937548330198
# function evaluations: 225
# ...best so far: -0.9999949456130164
# function evaluations: 227
# ...best so far: -0.999996560205377
# function evaluations: 229
# ...best so far: -0.9999970124219832
# function evaluations: 231
# ...best so far: -0.9999986139829037
# function evaluations: 233
# ...best so far: -0.9999986139829037
# function evaluations: 235
# ...best so far: -0.9999986139829037
# function evaluations: 237
# ...best so far: -0.9999986139829037
# function evaluations: 238
# ...best so far: -0.9999986139829037
# function evaluations: 239
# ...best so far: -0.9999989803250231
# function evaluations: 241
# ...best so far: -0.9999990642830348
# function evaluations: 243
# ...best so far: -0.9999993339611997
# function evaluations: 245
# ...best so far: -0.9999994236445126
# function evaluations: 247
# ...best so far: -0.9999994236445126
# function evaluations: 249
# ...best so far: -0.9999994407379504
# function evaluations: 251
# ...best so far: -0.9999996001105329
# function evaluations: 253
# ...best so far: -0.9999996001105329
# function evaluations: 255
# ...best so far: -0.9999996229829732
# function evaluations: 257
# ...best so far: -0.9999996229829732
# function evaluations: 259
# ...best so far: -0.9999996523411809
# function evaluations: 261
# ...best so far: -0.9999996740019013
# function evaluations: 263
# ...best so far: -0.9999996740019013
# function evaluations: 265
# ...best so far: -0.9999996792124477
# function evaluations: 267
# ...best so far: -0.9999996918676706
# function evaluations: 269
# ...best so far: -0.9999996918676706
# function evaluations: 271
# ...best so far: -0.9999997008918498
# function evaluations: 273
# ...best so far: -0.9999997008918498
# function evaluations: 275
# ...best so far: -0.9999997063587704
# function evaluations: 277
# ...best so far: -0.9999997063587704
# function evaluations: 279
# ...best so far: -0.9999997084721934
# function evaluations: 281
# ...best so far: -0.9999997084721934
# function evaluations: 282
# ...best so far: -0.9999997149848975
# function evaluations: 284
# ...best so far: -0.9999997149848975
# function evaluations: 285
# ...best so far: -0.9999997149848975
# function evaluations: 287
# ...best so far: -0.9999997211239229
# function evaluations: 289
# ...best so far: -0.9999997211239229
# function evaluations: 291
# ...best so far: -0.9999997211239229
# function evaluations: 292
# ...best so far: -0.9999997211239229
# function evaluations: 294
# ...best so far: -0.9999997279653569
# function evaluations: 296
# ...best so far: -0.9999997279653569
# function evaluations: 297
# ...best so far: -0.9999997377830379
# function evaluations: 299
# ...best so far: -0.9999997524806838
# function evaluations: 301
# ...best so far: -0.9999997524806838
# function evaluations: 302
# ...best so far: -0.9999997807014329
# function evaluations: 304
# ...best so far: -0.9999998039595036
# function evaluations: 306
# ...best so far: -0.9999998345834347
# function evaluations: 308
# ...best so far: -0.9999998874239066
# function evaluations: 310
# ...best so far: -0.9999999330260528
# function evaluations: 312
# ...best so far: -0.999999956429742
# function evaluations: 314
# ...best so far: -0.999999956429742
# function evaluations: 315
# ...best so far: -0.999999956429742
# function evaluations: 317
# ...best so far: -0.999999956429742
# function evaluations: 319
# ...best so far: -0.999999956429742
# function evaluations: 321
# ...best so far: -0.999999956429742
# function evaluations: 323
# ...best so far: -0.999999956429742
# function evaluations: 325
# ...best so far: -0.999999956429742
# function evaluations: 326
# ...best so far: -0.9999999624014257
# function evaluations: 328
# ...best so far: -0.9999999624014257
# function evaluations: 329
# ...best so far: -0.9999999667240828
# function evaluations: 331
# ...best so far: -0.9999999667240828
# function evaluations: 333
# ...best so far: -0.9999999769438658
# function evaluations: 335
# ...best so far: -0.9999999769438658
# function evaluations: 336
# ...best so far: -0.9999999769438658
# function evaluations: 338
# ...best so far: -0.9999999769438658
# function evaluations: 340
# ...best so far: -0.9999999769438658
# function evaluations: 341
# ...best so far: -0.9999999769438658
# function evaluations: 342
# ...best so far: -0.9999999769438658
# function evaluations: 343
# ...best so far: -0.9999999779524322
# function evaluations: 345
# ...best so far: -0.999999981276161
# function evaluations: 347
# ...best so far: -0.9999999826370215
# function evaluations: 349
# ...best so far: -0.9999999884951131
# function evaluations: 351
# ...best so far: -0.9999999884951131
# function evaluations: 352
# ...best so far: -0.9999999884951131
# function evaluations: 353
# ...best so far: -0.9999999893669417
# function evaluations: 355
# ...best so far: -0.9999999903291874
# function evaluations: 357
# ...best so far: -0.9999999911952194
# function evaluations: 359
# ...best so far: -0.9999999911952194
# function evaluations: 360
# ...best so far: -0.9999999916774817
# function evaluations: 362
# ...best so far: -0.9999999922680585
# function evaluations: 364
# ...best so far: -0.9999999922680585
# function evaluations: 365
# ...best so far: -0.9999999928065866
# function evaluations: 367
# ...best so far: -0.9999999928065866
# function evaluations: 368
# ...best so far: -0.9999999928065866
# function evaluations: 370
# ...best so far: -0.999999993106746
# function evaluations: 372
# ...best so far: -0.9999999933005665
# function evaluations: 374
# ...best so far: -0.9999999934255545
# function evaluations: 376
# ...best so far: -0.9999999938703946
# function evaluations: 378
# ...best so far: -0.9999999938703946
# function evaluations: 379
# ...best so far: -0.9999999942846513
# function evaluations: 381
# ...best so far: -0.9999999942846513
# function evaluations: 382
# ...best so far: -0.9999999951844993
# function evaluations: 384
# ...best so far: -0.9999999951844993
# function evaluations: 385
# ...best so far: -0.999999996521148
# function evaluations: 387
# ...best so far: -0.999999996521148
# function evaluations: 388
# ...best so far: -0.9999999976033651
# function evaluations: 390
# ...best so far: -0.9999999983608466
# function evaluations: 392
# ...best so far: -0.9999999983608466
# function evaluations: 394
# ...best so far: -0.9999999986298583
# function evaluations: 396
# ...best so far: -0.9999999988998822
# function evaluations: 398
# ...best so far: -0.9999999990780714
# function evaluations: 400
# ...best so far: -0.999999999293679
# function evaluations: 402
# ...best so far: -0.9999999995400985
# function evaluations: 404
# ...best so far: -0.9999999995484486
# function evaluations: 406
# ...best so far: -0.9999999995484486
# function evaluations: 408
# ...best so far: -0.9999999995754256
# function evaluations: 410
# ...best so far: -0.999999999630919
# function evaluations: 412
# ...best so far: -0.9999999997904206
# function evaluations: 414
# ...best so far: -0.9999999997904206
# function evaluations: 415
# ...best so far: -0.9999999997914876
# function evaluations: 417
# ...best so far: -0.9999999998355491
# function evaluations: 419
# ...best so far: -0.9999999998475864
# function evaluations: 421
# ...best so far: -0.9999999998863699
# function evaluations: 423
# ...best so far: -0.9999999999217898
# function evaluations: 425
# ...best so far: -0.9999999999217898
# function evaluations: 427
# ...best so far: -0.9999999999217898
# function evaluations: 429
# ...best so far: -0.9999999999493923
# function evaluations: 431
# ...best so far: -0.9999999999801453
# function evaluations: 433
# ...best so far: -0.9999999999801453
# function evaluations: 435
# ...best so far: -0.9999999999801453
# function evaluations: 436
# ...best so far: -0.9999999999801453
# function evaluations: 438
# ...best so far: -0.9999999999801453
# function evaluations: 440
# ...best so far: -0.999999999992504
# function evaluations: 442
# ...best so far: -0.999999999992504
# function evaluations: 443
# ...best so far: -0.999999999992504
# function evaluations: 445
# ...best so far: -0.999999999992504
# function evaluations: 447
# ...best so far: -0.9999999999934224
# function evaluations: 449
# ...best so far: -0.9999999999952636
# function evaluations: 451
# ...best so far: -0.9999999999952636
# function evaluations: 452
# ...best so far: -0.9999999999978784
# function evaluations: 454
# ...best so far: -0.9999999999978784
# function evaluations: 455
# ...best so far: -0.9999999999978784
# function evaluations: 457
# ...best so far: -0.9999999999978784
# function evaluations: 459
# ...best so far: -0.9999999999978784
# function evaluations: 461
# ...best so far: -0.9999999999978784
# function evaluations: 463
# ...best so far: -0.9999999999981547
# function evaluations: 465
# ...best so far: -0.999999999998389
# function evaluations: 467
# ...best so far: -0.9999999999991914
# function evaluations: 469
# ...best so far: -0.9999999999991914
# function evaluations: 471
# ...best so far: -0.9999999999991914
# function evaluations: 472
# ...best so far: -0.9999999999991914
# function evaluations: 474
# ...best so far: -0.9999999999993779
# function evaluations: 476
# ...best so far: -0.9999999999993779
# function evaluations: 478
# ...best so far: -0.9999999999993779
# function evaluations: 480
# ...best so far: -0.9999999999993779
# function evaluations: 481
# ...best so far: -0.9999999999993779
# function evaluations: 482
# ...best so far: -0.9999999999994805
# function evaluations: 484
# ...best so far: -0.9999999999994805
# function evaluations: 485
# ...best so far: -0.9999999999995255
# function evaluations: 487
# ...best so far: -0.999999999999576
# function evaluations: 489
# ...best so far: -0.999999999999576
# function evaluations: 491
# ...best so far: -0.999999999999576
# function evaluations: 492
# ...best so far: -0.9999999999996962
# function evaluations: 494
# ...best so far: -0.9999999999996962
# function evaluations: 495
# ...best so far: -0.9999999999997746
# function evaluations: 497
# ...best so far: -0.9999999999997746
# function evaluations: 498
# ...best so far: -0.9999999999998398
# function evaluations: 500
# ...best so far: -0.9999999999998398
# function evaluations: 501
# ...best so far: -0.9999999999998482
# function evaluations: 503
# ...best so far: -0.9999999999999091
# function evaluations: 505
# ...best so far: -0.9999999999999091
# function evaluations: 506
# ...best so far: -0.9999999999999091
# function evaluations: 507
# ...best so far: -0.999999999999928
# function evaluations: 509
# ...best so far: -0.9999999999999397
# function evaluations: 511
# ...best so far: -0.9999999999999641
# function evaluations: 513
# ...best so far: -0.9999999999999656
# function evaluations: 515
# ...best so far: -0.9999999999999742
# function evaluations: 517
# ...best so far: -0.9999999999999742
# function evaluations: 519
# ...best so far: -0.9999999999999837
# function evaluations: 521
# ...best so far: -0.9999999999999837
# function evaluations: 522
# ...best so far: -0.9999999999999937
# function evaluations: 524
# ...best so far: -0.9999999999999966
# function evaluations: 526
# ...best so far: -0.9999999999999966
# function evaluations: 528
# ...best so far: -0.9999999999999966
# function evaluations: 529
# ...best so far: -0.9999999999999966
# function evaluations: 531
# ...best so far: -0.9999999999999966
# function evaluations: 533
# ...best so far: -0.999999999999997
# function evaluations: 535
# ...best so far: -0.999999999999998
# function evaluations: 537
# ...best so far: -0.9999999999999988
# function evaluations: 539
# ...best so far: -0.9999999999999988
# function evaluations: 540
# ...best so far: -0.9999999999999989
# function evaluations: 542
# ...best so far: -0.9999999999999991
# function evaluations: 544
# ...best so far: -0.9999999999999992
# function evaluations: 546
# ...best so far: -0.9999999999999993
# function evaluations: 548
# ...best so far: -0.9999999999999994
# function evaluations: 550
# ...best so far: -0.9999999999999994
# function evaluations: 551
# ...best so far: -0.9999999999999997
# function evaluations: 553
# ...best so far: -0.9999999999999997
# function evaluations: 554
# ...best so far: -0.9999999999999997
# function evaluations: 555
# ...best so far: -0.9999999999999997
# function evaluations: 557
# ...best so far: -0.9999999999999997
# function evaluations: 559
# ...best so far: -0.9999999999999999
# function evaluations: 561
# ...best so far: -0.9999999999999999
# function evaluations: 562
# ...best so far: -0.9999999999999999
# function evaluations: 564
# ...best so far: -0.9999999999999999
# function evaluations: 566
# Best score: [array([ 0.00000000e+00, -1.08238608e-08,  4.79329700e-17]), -0.9999999999999999]
# Iterations: 321
# Function evaluations: 572
