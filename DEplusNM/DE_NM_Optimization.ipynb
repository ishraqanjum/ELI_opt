# %%
import sys
from bayes_opt import BayesianOptimization
from L1_DifferentialEvolution import extract_data, model, diff_evolution
from NelderMead import bounded_nelder_mead
import math
import physics
from losses import Losses
from scipy.optimize import Bounds
from scipy.optimize import minimize
from pyswarm import pso
import numpy as np
import matplotlib.pyplot as plt

# %%
frequency, intensity = extract_data() # extracting the desired information

# compressor parameters - obtained as minus the stretcher one - TO BE FIXED WITH REAL ONES ONCE THEY ARE AVAILABLE
COMPRESSOR = -1 * np.array((267.422 * 1e-24, -2.384 * 1e-36, 9.54893 * 1e-50)) # in s^2, s^3 and s^4 (SI units)
# non linearity parameter
B = 2
# cutoff frequencies, in THz, used to remove noise - derived from visual inspection
CUTOFF = (289.95, 291.91)
# model instantiation
l1_pump = model(frequency, intensity, COMPRESSOR, B, CUTOFF, num_points=int(5e3))

losses = Losses(l1_pump)

bounds_DE = Bounds(
            # GDD         # TOD          # FOD
    lb = (2.3522e-22, -1.003635e-34, 4.774465e-50),
    ub = (2.99624e-22, 9.55955e-35, 1.4323395e-49)
)

bounds_matrix = np.vstack((bounds_DE.lb, bounds_DE.ub)).T
disp_bounds = np.sort(l1_pump.translate_control(bounds_matrix, verse = "to_disp"))

# %%
# cross_p, mutation, pop_size = optimizer.max["params"].values()
cross_p = 0.6903393772628603
mutation = 1.3025469798237372
pop_size = 35
# training with the best parameters and increased number of iterations
candidate_best = diff_evolution(
        objective_function = losses.loss3,
        bounds = disp_bounds,
        mutation = mutation, 
        cross_p = cross_p, 
        population_size = int(pop_size),
        verbose = 1, 
        maxit = 45, 
        print_every = 1
)
print(losses.loss3(candidate_best))
print(candidate_best)
# Out:
# Iteration 0 - Objective Function value: 25.433320327863086
# Iteration 1 - Objective Function value: 25.433320327863086
# Iteration 2 - Objective Function value: 25.433320327863086
# Iteration 3 - Objective Function value: 21.177366607608416
# Iteration 4 - Objective Function value: 13.874302915155301
# Iteration 5 - Objective Function value: 13.874302915155301
# Iteration 6 - Objective Function value: 12.366970204627705
# Iteration 7 - Objective Function value: 2.8240837255857065
# Iteration 8 - Objective Function value: 2.8240837255857065
# Iteration 9 - Objective Function value: 2.8240837255857065
# Iteration 10 - Objective Function value: 2.8240837255857065
# Iteration 11 - Objective Function value: 2.8240837255857065
# Iteration 12 - Objective Function value: 2.8240837255857065
# Iteration 13 - Objective Function value: 2.8240837255857065
# Iteration 14 - Objective Function value: 2.8240837255857065
# Iteration 15 - Objective Function value: 2.8240837255857065
# Iteration 16 - Objective Function value: 2.8240837255857065
# Iteration 17 - Objective Function value: 2.8240837255857065
# Iteration 18 - Objective Function value: 2.8240837255857065
# Iteration 19 - Objective Function value: 2.8240837255857065
# Iteration 20 - Objective Function value: 2.8240837255857065
# Iteration 21 - Objective Function value: 2.8240837255857065
# Iteration 22 - Objective Function value: 2.8240837255857065
# Iteration 23 - Objective Function value: 2.8240837255857065
# Iteration 24 - Objective Function value: 2.8240837255857065
# Iteration 25 - Objective Function value: 2.8240837255857065
# Iteration 26 - Objective Function value: 2.8240837255857065
# Iteration 27 - Objective Function value: 2.8240837255857065
# Iteration 28 - Objective Function value: 2.8240837255857065
# Iteration 29 - Objective Function value: 2.8240837255857065
# Iteration 30 - Objective Function value: 2.8240837255857065
# Iteration 31 - Objective Function value: 2.8240837255857065
# Iteration 32 - Objective Function value: 2.8240837255857065
# Iteration 33 - Objective Function value: 2.8240837255857065
# Iteration 34 - Objective Function value: 2.8240837255857065
# Iteration 35 - Objective Function value: 2.8240837255857065
# Iteration 36 - Objective Function value: 2.8240837255857065
# Iteration 37 - Objective Function value: 2.4940855878802153
# Iteration 38 - Objective Function value: 2.4940855878802153
# Iteration 39 - Objective Function value: 2.4738979061825495
# Iteration 40 - Objective Function value: 2.4738979061825495
# Iteration 41 - Objective Function value: 2.4738979061825495
# Iteration 42 - Objective Function value: 2.4738979061825495
# Iteration 43 - Objective Function value: 2.4738979061825495
# Iteration 44 - Objective Function value: 2.4738979061825495
#  Iterations = 1575
# 2.4738979061825495
# [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]

# %%
# alpha, gamma, rho, sigma = optimizer.max["params"].values()

# Define parameters and bounds
print_NM_progress = 1
bounds=((-5.31305788e-01, -4.17101926e-01), (-3.14772231e+08, 3.01620182e+08), (-2.55151879e+15, 1.56859005e+15))

# Run the optimization using Nelder-Mead method
res = bounded_nelder_mead(losses.loss3, candidate_best, disp_bounds, print_NM_progress)

# Print the results
print(res.x)
print(res.fun)
print(res.message)
print('iterations:', res.nit)
print('function evaluations:', res.nfev)
# Out:
# iteration: 1
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 2
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 3
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 4
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 5
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 6
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 7
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 8
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 9
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 10
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 11
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 12
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 13
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 14
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 15
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 16
# best value of objective function so far: 2.4738979061825495
# best candidate: [-4.75846775e-01 -7.93497946e+06  1.56859005e+15]
# iteration: 17
# best value of objective function so far: 1.507466551296255
# best candidate: [-4.75443172e-01 -7.08301267e+06  1.56859005e+15]
# iteration: 18
# best value of objective function so far: 1.507466551296255
# best candidate: [-4.75443172e-01 -7.08301267e+06  1.56859005e+15]
# iteration: 19
# best value of objective function so far: 1.507466551296255
# best candidate: [-4.75443172e-01 -7.08301267e+06  1.56859005e+15]
# iteration: 20
# best value of objective function so far: 1.507466551296255
# best candidate: [-4.75443172e-01 -7.08301267e+06  1.56859005e+15]
# iteration: 21
# best value of objective function so far: 1.507466551296255
# best candidate: [-4.75443172e-01 -7.08301267e+06  1.56859005e+15]
# iteration: 22
# best value of objective function so far: 1.507466551296255
# best candidate: [-4.75443172e-01 -7.08301267e+06  1.56859005e+15]
# iteration: 23
# best value of objective function so far: 1.507466551296255
# best candidate: [-4.75443172e-01 -7.08301267e+06  1.56859005e+15]
# iteration: 24
# best value of objective function so far: 1.4499686667328806
# best candidate: [-4.75480108e-01 -6.90947507e+06  1.56859005e+15]
# iteration: 25
# best value of objective function so far: 1.4499686667328806
# best candidate: [-4.75480108e-01 -6.90947507e+06  1.56859005e+15]
# iteration: 26
# best value of objective function so far: 1.4499686667328806
# best candidate: [-4.75480108e-01 -6.90947507e+06  1.56859005e+15]
# iteration: 27
# best value of objective function so far: 1.4488135152816632
# best candidate: [-4.75445560e-01 -6.96412142e+06  1.56859005e+15]
# iteration: 28
# best value of objective function so far: 1.4488135152816632
# best candidate: [-4.75445560e-01 -6.96412142e+06  1.56859005e+15]
# iteration: 29
# best value of objective function so far: 1.4488135152816632
# best candidate: [-4.75445560e-01 -6.96412142e+06  1.56859005e+15]
# iteration: 30
# best value of objective function so far: 1.4488135152816632
# best candidate: [-4.75445560e-01 -6.96412142e+06  1.56859005e+15]
# iteration: 31
# best value of objective function so far: 1.4437938118304265
# best candidate: [-4.75468861e-01 -6.96216476e+06  1.56859005e+15]
# iteration: 32
# best value of objective function so far: 1.4437938118304265
# best candidate: [-4.75468861e-01 -6.96216476e+06  1.56859005e+15]
# iteration: 33
# best value of objective function so far: 1.443761917237969
# best candidate: [-4.75478557e-01 -6.94933615e+06  1.56859005e+15]
# iteration: 34
# best value of objective function so far: 1.443761917237969
# best candidate: [-4.75478557e-01 -6.94933615e+06  1.56859005e+15]
# iteration: 35
# best value of objective function so far: 1.4434412033726196
# best candidate: [-4.75467123e-01 -6.95096876e+06  1.56859005e+15]
# iteration: 36
# best value of objective function so far: 1.4434412033726196
# best candidate: [-4.75467123e-01 -6.95096876e+06  1.56859005e+15]
# iteration: 37
# best value of objective function so far: 1.4433944287379994
# best candidate: [-4.75470253e-01 -6.95563755e+06  1.56859005e+15]
# iteration: 38
# best value of objective function so far: 1.4433229619189705
# best candidate: [-4.75472147e-01 -6.95215427e+06  1.56859005e+15]
# iteration: 39
# best value of objective function so far: 1.4433229619189705
# best candidate: [-4.75472147e-01 -6.95215427e+06  1.56859005e+15]
# [-4.75472147e-01 -6.95215427e+06  1.56859005e+15]
# 1.4433229619189705
# Maximum number of iterations not exceeded
# iterations: 39
# function evaluations: 75
