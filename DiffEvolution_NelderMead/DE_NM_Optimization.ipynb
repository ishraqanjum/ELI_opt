# %%
import sys
from bayes_opt import BayesianOptimization
from L1_DifferentialEvolution import extract_data, model, diff_evolution
from NelderMead import bounded_nelder_mead
import math
import physics
from losses import Losses
from scipy.optimize import Bounds
from scipy.optimize import minimize
from pyswarm import pso
import numpy as np
import matplotlib.pyplot as plt

# %%
frequency, intensity = extract_data() # extracting the desired information

# compressor parameters - obtained as minus the stretcher one - TO BE FIXED WITH REAL ONES ONCE THEY ARE AVAILABLE
COMPRESSOR = -1 * np.array((267.422 * 1e-24, -2.384 * 1e-36, 9.54893 * 1e-50)) # in s^2, s^3 and s^4 (SI units)
# non linearity parameter
B = 2
# cutoff frequencies, in THz, used to remove noise - derived from visual inspection
CUTOFF = (289.95, 291.91)
# model instantiation
l1_pump = model(frequency, intensity, COMPRESSOR, B, CUTOFF, num_points=int(5e3))

losses = Losses(l1_pump)

bounds_DE = Bounds(
            # GDD         # TOD          # FOD
    lb = (2.3522e-22, -1.003635e-34, 4.774465e-50),
    ub = (2.99624e-22, 9.55955e-35, 1.4323395e-49)
)

bounds_matrix = np.vstack((bounds_DE.lb, bounds_DE.ub)).T
disp_bounds = np.sort(l1_pump.translate_control(bounds_matrix, verse = "to_disp"))

# %%
# cross_p, mutation, pop_size = optimizer.max["params"].values()
cross_p = 0.6903393772628603
mutation = 1.3025469798237372
pop_size = 35
# training with the best parameters and increased number of iterations
candidate_best = diff_evolution(
        objective_function = losses.loss3,
        bounds = disp_bounds,
        mutation = mutation, 
        cross_p = cross_p, 
        population_size = int(pop_size),
        verbose = 1, 
        maxit = 45, 
        print_every = 1
)
print(losses.loss3(candidate_best))
print(candidate_best)
# Out:
# Iteration 0 - Objective Function value: 29.4345202008257
# Iteration 1 - Objective Function value: 29.4345202008257
# Iteration 2 - Objective Function value: 29.4345202008257
# Iteration 3 - Objective Function value: 29.4345202008257
# Iteration 4 - Objective Function value: 29.4345202008257
# Iteration 5 - Objective Function value: 29.4345202008257
# Iteration 6 - Objective Function value: 26.421405913017562
# Iteration 7 - Objective Function value: 26.421405913017562
# Iteration 8 - Objective Function value: 26.421405913017562
# Iteration 9 - Objective Function value: 16.914259971808498
# Iteration 10 - Objective Function value: 16.914259971808498
# Iteration 11 - Objective Function value: 16.914259971808498
# Iteration 12 - Objective Function value: 16.914259971808498
# Iteration 13 - Objective Function value: 16.914259971808498
# Iteration 14 - Objective Function value: 16.914259971808498
# Iteration 15 - Objective Function value: 16.914259971808498
# Iteration 16 - Objective Function value: 16.914259971808498
# Iteration 17 - Objective Function value: 2.381358563542093
# Iteration 18 - Objective Function value: 2.381358563542093
# Iteration 19 - Objective Function value: 2.381358563542093
# Iteration 20 - Objective Function value: 2.381358563542093
# Iteration 21 - Objective Function value: 2.381358563542093
# Iteration 22 - Objective Function value: 2.381358563542093
# Iteration 23 - Objective Function value: 2.381358563542093
# Iteration 24 - Objective Function value: 2.381358563542093
# Iteration 25 - Objective Function value: 2.381358563542093
# Iteration 26 - Objective Function value: 2.381358563542093
# Iteration 27 - Objective Function value: 2.381358563542093
# Iteration 28 - Objective Function value: 2.381358563542093
# Iteration 29 - Objective Function value: 2.381358563542093
# Iteration 30 - Objective Function value: 2.381358563542093
# Iteration 31 - Objective Function value: 2.381358563542093
# Iteration 32 - Objective Function value: 2.381358563542093
# Iteration 33 - Objective Function value: 2.381358563542093
# Iteration 34 - Objective Function value: 2.381358563542093
# Iteration 35 - Objective Function value: 2.381358563542093
# Iteration 36 - Objective Function value: 2.381358563542093
# Iteration 37 - Objective Function value: 2.381358563542093
# Iteration 38 - Objective Function value: 2.381358563542093
# Iteration 39 - Objective Function value: 2.381358563542093
# Iteration 40 - Objective Function value: 2.381358563542093
# Iteration 41 - Objective Function value: 2.381358563542093
# Iteration 42 - Objective Function value: 2.381358563542093
# Iteration 43 - Objective Function value: 2.381358563542093
# Iteration 44 - Objective Function value: 2.381358563542093
#  Iterations = 1575
# 2.381358563542093
# [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]

# %%
# alpha, gamma, rho, sigma = optimizer.max["params"].values()

# Define parameters and bounds
print_NM_progress = 1
bounds=((-5.31305788e-01, -4.17101926e-01), (-3.14772231e+08, 3.01620182e+08), (-2.55151879e+15, 1.56859005e+15))

# Run the optimization using Nelder-Mead method
res = bounded_nelder_mead(losses.loss3, candidate_best, disp_bounds, print_NM_progress)

# Print the results
print(res.x)
print(res.fun)
print(res.message)
print('iterations:', res.nit)
print('function evaluations:', res.nfev)
# Out:
# iteration: 1
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 2
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 3
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 4
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 5
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 6
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 7
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 8
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 9
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 10
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 11
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 12
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 13
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 14
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 15
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 16
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 17
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 18
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 19
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 20
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 21
# best value of objective function so far: 2.381358563542083
# best candidate: [-4.75492946e-01 -7.81365189e+06  1.56859005e+15]
# iteration: 22
# best value of objective function so far: 1.503951531303094
# best candidate: [-4.75520350e-01 -6.73275842e+06  1.56859005e+15]
# iteration: 23
# best value of objective function so far: 1.503951531303094
# best candidate: [-4.75520350e-01 -6.73275842e+06  1.56859005e+15]
# iteration: 24
# best value of objective function so far: 1.503951531303094
# best candidate: [-4.75520350e-01 -6.73275842e+06  1.56859005e+15]
# iteration: 25
# best value of objective function so far: 1.503951531303094
# best candidate: [-4.75520350e-01 -6.73275842e+06  1.56859005e+15]
# iteration: 26
# best value of objective function so far: 1.503951531303094
# best candidate: [-4.75520350e-01 -6.73275842e+06  1.56859005e+15]
# iteration: 27
# best value of objective function so far: 1.503951531303094
# best candidate: [-4.75520350e-01 -6.73275842e+06  1.56859005e+15]
# iteration: 28
# best value of objective function so far: 1.503951531303094
# best candidate: [-4.75520350e-01 -6.73275842e+06  1.56859005e+15]
# iteration: 29
# best value of objective function so far: 1.490019175985307
# best candidate: [-4.75543450e-01 -6.91528222e+06  1.56859005e+15]
# iteration: 30
# best value of objective function so far: 1.4860774311353895
# best candidate: [-4.75441569e-01 -6.75203693e+06  1.56859005e+15]
# iteration: 31
# best value of objective function so far: 1.4751194449599556
# best candidate: [-4.75527537e-01 -6.90539472e+06  1.56859005e+15]
# iteration: 32
# best value of objective function so far: 1.4508673146193487
# best candidate: [-4.75488020e-01 -6.98238416e+06  1.56859005e+15]
# iteration: 33
# best value of objective function so far: 1.4508673146193487
# best candidate: [-4.75488020e-01 -6.98238416e+06  1.56859005e+15]
# iteration: 34
# best value of objective function so far: 1.4508673146193487
# best candidate: [-4.75488020e-01 -6.98238416e+06  1.56859005e+15]
# iteration: 35
# best value of objective function so far: 1.4508673146193487
# best candidate: [-4.75488020e-01 -6.98238416e+06  1.56859005e+15]
# iteration: 36
# best value of objective function so far: 1.4508673146193487
# best candidate: [-4.75488020e-01 -6.98238416e+06  1.56859005e+15]
# iteration: 37
# best value of objective function so far: 1.4508673146193487
# best candidate: [-4.75488020e-01 -6.98238416e+06  1.56859005e+15]
# iteration: 38
# best value of objective function so far: 1.447952063304402
# best candidate: [-4.75471196e-01 -6.91624904e+06  1.56859005e+15]
# iteration: 39
# best value of objective function so far: 1.446050166213552
# best candidate: [-4.75454736e-01 -6.94408179e+06  1.56859005e+15]
# iteration: 40
# best value of objective function so far: 1.446018904763613
# best candidate: [-4.75464692e-01 -6.92783667e+06  1.56859005e+15]
# iteration: 41
# best value of objective function so far: 1.443646966434176
# best candidate: [-4.75475781e-01 -6.95588666e+06  1.56859005e+15]
# iteration: 42
# best value of objective function so far: 1.443646966434176
# best candidate: [-4.75475781e-01 -6.95588666e+06  1.56859005e+15]
# iteration: 43
# best value of objective function so far: 1.443646966434176
# best candidate: [-4.75475781e-01 -6.95588666e+06  1.56859005e+15]
# iteration: 44
# best value of objective function so far: 1.443601818308932
# best candidate: [-4.75467835e-01 -6.94434240e+06  1.56859005e+15]
# iteration: 45
# best value of objective function so far: 1.443601818308932
# best candidate: [-4.75467835e-01 -6.94434240e+06  1.56859005e+15]
# iteration: 46
# best value of objective function so far: 1.4435088538647984
# best candidate: [-4.75474114e-01 -6.95568972e+06  1.56859005e+15]
# iteration: 47
# best value of objective function so far: 1.4434302893194315
# best candidate: [-4.75469509e-01 -6.95638609e+06  1.56859005e+15]
# iteration: 48
# best value of objective function so far: 1.443394346146035
# best candidate: [-4.75473133e-01 -6.95401303e+06  1.56859005e+15]
# iteration: 49
# best value of objective function so far: 1.4433183528531386
# best candidate: [-4.75470044e-01 -6.94985267e+06  1.56859005e+15]
# [-4.75470044e-01 -6.94985267e+06  1.56859005e+15]
# 1.4433183528531386
# Maximum number of iterations not exceeded
# iterations: 49
# function evaluations: 90
