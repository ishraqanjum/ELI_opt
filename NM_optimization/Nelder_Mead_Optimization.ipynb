# %%
from bayes_opt import BayesianOptimization
from L1_DifferentialEvolution import extract_data, model, diff_evolution
from scipy.optimize import Bounds
from scipy.optimize import minimize
from NelderMead import bounded_nelder_mead
from losses import Losses
import math
import physics
import numpy as np
import matplotlib.pyplot as plt

# %%
frequency, intensity = extract_data() # extracting the desired information

# compressor parameters - obtained as minus the stretcher one - TO BE FIXED WITH REAL ONES ONCE THEY ARE AVAILABLE
COMPRESSOR = -1 * np.array((267.422 * 1e-24, -2.384 * 1e-36, 9.54893 * 1e-50)) # in s^2, s^3 and s^4 (SI units)
# non linearity parameter
B = 2
# cutoff frequencies, in THz, used to remove noise - derived from visual inspection
CUTOFF = (289.95, 291.91)
# model instantiation
l1_pump = model(frequency, intensity, COMPRESSOR, B, CUTOFF, num_points=int(5e3))

losses = Losses(l1_pump)

bounds_DE = Bounds(
            # GDD         # TOD          # FOD
    lb = (2.3522e-22, -1.003635e-34, 4.774465e-50),
    ub = (2.99624e-22, 9.55955e-35, 1.4323395e-49)
)

bounds_matrix = np.vstack((bounds_DE.lb, bounds_DE.ub)).T
disp_bounds = np.sort(l1_pump.translate_control(bounds_matrix, verse = "to_disp"))

# %%
# Define the bounds
bounds = np.array(((-5.31305788e-01, -4.17101926e-01), (-3.14772231e+08, 3.01620182e+08), (-2.55151879e+15, 1.56859005e+15)))

# Generate a random list within the bounds
random_values = [np.random.uniform(low=low, high=high) for low, high in bounds]

print(random_values)
print_progress = 1
# Run the optimization using Nelder-Mead method
res = bounded_nelder_mead(losses.loss3, random_values, bounds, print_progress)

# Print the results
print(res.x)
print(res.fun)
print(res.message)
print('iterations:', res.nit)
print('function evaluations:', res.nfev)
# Out:
# [-0.4201788919048792, 125058602.7745133, 1343413647389464.5]
# iteration: 1
# best value of objective function so far: 167.30960438528356
# best candidate: [-4.20178892e-01  1.25058603e+08  1.56859005e+15]
# iteration: 2
# best value of objective function so far: 106.7122135094969
# best candidate: [-4.17769870e-01 -1.13081312e+08  1.51970906e+15]
# iteration: 3
# best value of objective function so far: 106.7122135094969
# best candidate: [-4.17769870e-01 -1.13081312e+08  1.51970906e+15]
# iteration: 4
# best value of objective function so far: 106.7122135094969
# best candidate: [-4.17769870e-01 -1.13081312e+08  1.51970906e+15]
# iteration: 5
# best value of objective function so far: 106.7122135094969
# best candidate: [-4.17769870e-01 -1.13081312e+08  1.51970906e+15]
# iteration: 6
# best value of objective function so far: 106.7122135094969
# best candidate: [-4.17769870e-01 -1.13081312e+08  1.51970906e+15]
# iteration: 7
# best value of objective function so far: 106.7122135094969
# best candidate: [-4.17769870e-01 -1.13081312e+08  1.51970906e+15]
# iteration: 8
# best value of objective function so far: 106.7122135094969
# best candidate: [-4.17769870e-01 -1.13081312e+08  1.51970906e+15]
# iteration: 9
# best value of objective function so far: 106.7122135094969
# best candidate: [-4.17769870e-01 -1.13081312e+08  1.51970906e+15]
# iteration: 10
# best value of objective function so far: 106.7122135094969
# best candidate: [-4.17769870e-01 -1.13081312e+08  1.51970906e+15]
# iteration: 11
# best value of objective function so far: 105.42464638284711
# best candidate: [-4.18915466e-01 -1.58483453e+08  1.54772374e+15]
# iteration: 12
# best value of objective function so far: 104.9107211326674
# best candidate: [-4.18394451e-01 -1.30322170e+08  1.54001287e+15]
# iteration: 13
# best value of objective function so far: 104.9107211326674
# best candidate: [-4.18394451e-01 -1.30322170e+08  1.54001287e+15]
# iteration: 14
# best value of objective function so far: 104.86515656706698
# best candidate: [-4.18277174e-01 -1.33793085e+08  1.53330454e+15]
# iteration: 15
# best value of objective function so far: 104.8218196529129
# best candidate: [-4.18572462e-01 -1.45622423e+08  1.54077383e+15]
# iteration: 16
# best value of objective function so far: 104.79549312011093
# best candidate: [-4.18420769e-01 -1.41486246e+08  1.53747542e+15]
# iteration: 17
# best value of objective function so far: 104.66179700238762
# best candidate: [-4.18412615e-01 -1.36568473e+08  1.53824242e+15]
# iteration: 18
# best value of objective function so far: 104.66179700238762
# best candidate: [-4.18412615e-01 -1.36568473e+08  1.53824242e+15]
# iteration: 19
# best value of objective function so far: 104.66179700238762
# best candidate: [-4.18412615e-01 -1.36568473e+08  1.53824242e+15]
# iteration: 20
# best value of objective function so far: 104.6496254482775
# best candidate: [-4.18434993e-01 -1.35166653e+08  1.53849362e+15]
# iteration: 21
# best value of objective function so far: 104.6496254482775
# best candidate: [-4.18434993e-01 -1.35166653e+08  1.53849362e+15]
# iteration: 22
# best value of objective function so far: 104.62896747105934
# best candidate: [-4.18469338e-01 -1.34423402e+08  1.54037301e+15]
# iteration: 23
# best value of objective function so far: 104.52137173436714
# best candidate: [-4.18545119e-01 -1.34430113e+08  1.54122754e+15]
# iteration: 24
# best value of objective function so far: 104.52137173436714
# best candidate: [-4.18545119e-01 -1.34430113e+08  1.54122754e+15]
# iteration: 25
# best value of objective function so far: 104.37887040490149
# best candidate: [-4.18661575e-01 -1.34447624e+08  1.54555718e+15]
# iteration: 26
# best value of objective function so far: 104.19475353231874
# best candidate: [-4.18811468e-01 -1.36624031e+08  1.54684849e+15]
# iteration: 27
# best value of objective function so far: 103.7280872356558
# best candidate: [-4.19270925e-01 -1.32500302e+08  1.55958347e+15]
# iteration: 28
# best value of objective function so far: 102.82402441871227
# best candidate: [-4.19981145e-01 -1.34794902e+08  1.56859005e+15]
# iteration: 29
# best value of objective function so far: 101.24910609246457
# best candidate: [-4.21354336e-01 -1.35194206e+08  1.56859005e+15]
# iteration: 30
# best value of objective function so far: 97.7467836450013
# best candidate: [-4.24215617e-01 -1.27060971e+08  1.56859005e+15]
# iteration: 31
# best value of objective function so far: 92.06111070020916
# best candidate: [-4.29294659e-01 -1.31916330e+08  1.56859005e+15]
# iteration: 32
# best value of objective function so far: 81.9591226418401
# best candidate: [-4.39309097e-01 -1.21565370e+08  1.56859005e+15]
# iteration: 33
# best value of objective function so far: 66.38872528571962
# best candidate: [-4.58603512e-01 -1.02759039e+08  1.56859005e+15]
# iteration: 34
# best value of objective function so far: 66.38872528571962
# best candidate: [-4.58603512e-01 -1.02759039e+08  1.56859005e+15]
# iteration: 35
# best value of objective function so far: 66.38872528571962
# best candidate: [-4.58603512e-01 -1.02759039e+08  1.56859005e+15]
# iteration: 36
# best value of objective function so far: 66.38872528571962
# best candidate: [-4.58603512e-01 -1.02759039e+08  1.56859005e+15]
# iteration: 37
# best value of objective function so far: 63.14061678458307
# best candidate: [-4.72119675e-01 -9.67185979e+07  1.56859005e+15]
# iteration: 38
# best value of objective function so far: 62.4515203501273
# best candidate: [-4.53342448e-01 -8.59185962e+07  1.56859005e+15]
# iteration: 39
# best value of objective function so far: 44.02977271647839
# best candidate: [-4.66472794e-01 -6.25102475e+07  1.56859005e+15]
# iteration: 40
# best value of objective function so far: 18.365657803684545
# best candidate: [-4.79490016e-01 -2.09848466e+07  1.56859005e+15]
# iteration: 41
# best value of objective function so far: 18.365657803684545
# best candidate: [-4.79490016e-01 -2.09848466e+07  1.56859005e+15]
# iteration: 42
# best value of objective function so far: 18.365657803684545
# best candidate: [-4.79490016e-01 -2.09848466e+07  1.56859005e+15]
# iteration: 43
# best value of objective function so far: 18.33385867919131
# best candidate: [-4.72470262e-01 -1.93844576e+07  1.56859005e+15]
# iteration: 44
# best value of objective function so far: 18.33385867919131
# best candidate: [-4.72470262e-01 -1.93844576e+07  1.56859005e+15]
# iteration: 45
# best value of objective function so far: 18.33385867919131
# best candidate: [-4.72470262e-01 -1.93844576e+07  1.56859005e+15]
# iteration: 46
# best value of objective function so far: 11.324627504832167
# best candidate: [-4.76872737e-01 -1.84768174e+07  1.56859005e+15]
# iteration: 47
# best value of objective function so far: 11.324627504832167
# best candidate: [-4.76872737e-01 -1.84768174e+07  1.56859005e+15]
# iteration: 48
# best value of objective function so far: 10.299455127263988
# best candidate: [-4.78079255e-01 -1.37452879e+07  1.56859005e+15]
# iteration: 49
# best value of objective function so far: 10.299455127263988
# best candidate: [-4.78079255e-01 -1.37452879e+07  1.56859005e+15]
# iteration: 50
# best value of objective function so far: 10.18674803946633
# best candidate: [-4.75614837e-01 -1.65965872e+07  1.56859005e+15]
# iteration: 51
# best value of objective function so far: 8.84429194622857
# best candidate: [-4.75779738e-01 -1.51618613e+07  1.56859005e+15]
# iteration: 52
# best value of objective function so far: 4.518117707317396
# best candidate: [-4.75976777e-01 -1.07049796e+07  1.56859005e+15]
# iteration: 53
# best value of objective function so far: 4.518117707317396
# best candidate: [-4.75976777e-01 -1.07049796e+07  1.56859005e+15]
# iteration: 54
# best value of objective function so far: 4.518117707317396
# best candidate: [-4.75976777e-01 -1.07049796e+07  1.56859005e+15]
# iteration: 55
# best value of objective function so far: 4.518117707317396
# best candidate: [-4.75976777e-01 -1.07049796e+07  1.56859005e+15]
# iteration: 56
# best value of objective function so far: 3.9766460552341805
# best candidate: [-4.75937333e-01 -6.32709959e+06  1.56859005e+15]
# iteration: 57
# best value of objective function so far: 3.9766460552341805
# best candidate: [-4.75937333e-01 -6.32709959e+06  1.56859005e+15]
# iteration: 58
# best value of objective function so far: 3.6819597403887405
# best candidate: [-4.76344329e-01 -8.97070691e+06  1.56859005e+15]
# iteration: 59
# best value of objective function so far: 3.4042775524366564
# best candidate: [-4.76100021e-01 -9.31054300e+06  1.56859005e+15]
# iteration: 60
# best value of objective function so far: 3.4042775524366564
# best candidate: [-4.76100021e-01 -9.31054300e+06  1.56859005e+15]
# iteration: 61
# best value of objective function so far: 3.4042775524366564
# best candidate: [-4.76100021e-01 -9.31054300e+06  1.56859005e+15]
# iteration: 62
# best value of objective function so far: 3.2630340454863545
# best candidate: [-4.76158072e-01 -7.99939731e+06  1.56859005e+15]
# iteration: 63
# best value of objective function so far: 3.1437483679587386
# best candidate: [-4.76126136e-01 -8.72070975e+06  1.56859005e+15]
# iteration: 64
# best value of objective function so far: 3.1437483679587386
# best candidate: [-4.76126136e-01 -8.72070975e+06  1.56859005e+15]
# iteration: 65
# best value of objective function so far: 3.1437483679587386
# best candidate: [-4.76126136e-01 -8.72070975e+06  1.56859005e+15]
# iteration: 66
# best value of objective function so far: 3.114121681203644
# best candidate: [-4.76133909e-01 -8.19320774e+06  1.56859005e+15]
# iteration: 67
# best value of objective function so far: 3.114121681203644
# best candidate: [-4.76133909e-01 -8.19320774e+06  1.56859005e+15]
# iteration: 68
# best value of objective function so far: 3.114121681203644
# best candidate: [-4.76133909e-01 -8.19320774e+06  1.56859005e+15]
# iteration: 69
# best value of objective function so far: 3.0707670951662442
# best candidate: [-4.76125808e-01 -8.35715537e+06  1.56859005e+15]
# iteration: 70
# best value of objective function so far: 3.069031754152296
# best candidate: [-4.76077689e-01 -7.82496539e+06  1.56859005e+15]
# iteration: 71
# best value of objective function so far: 3.06865011568258
# best candidate: [-4.76105847e-01 -8.02562653e+06  1.56859005e+15]
# iteration: 72
# best value of objective function so far: 2.8603349222907304
# best candidate: [-4.76014242e-01 -7.71150316e+06  1.56859005e+15]
# iteration: 73
# best value of objective function so far: 2.8603349222907304
# best candidate: [-4.76014242e-01 -7.71150316e+06  1.56859005e+15]
# iteration: 74
# best value of objective function so far: 2.8603349222907304
# best candidate: [-4.76014242e-01 -7.71150316e+06  1.56859005e+15]
# iteration: 75
# best value of objective function so far: 2.5768432330975646
# best candidate: [-4.75903010e-01 -7.68903714e+06  1.56859005e+15]
# iteration: 76
# best value of objective function so far: 2.1054890858549498
# best candidate: [-4.75713540e-01 -7.18370233e+06  1.56859005e+15]
# iteration: 77
# best value of objective function so far: 1.691193364484397
# best candidate: [-4.75632192e-01 -6.80616938e+06  1.56859005e+15]
# iteration: 78
# best value of objective function so far: 1.6887321707519467
# best candidate: [-4.75392616e-01 -6.57188235e+06  1.56859005e+15]
# iteration: 79
# best value of objective function so far: 1.6887321707519467
# best candidate: [-4.75392616e-01 -6.57188235e+06  1.56859005e+15]
# iteration: 80
# best value of objective function so far: 1.6887321707519467
# best candidate: [-4.75392616e-01 -6.57188235e+06  1.56859005e+15]
# iteration: 81
# best value of objective function so far: 1.520892118962812
# best candidate: [-4.75556859e-01 -6.80626916e+06  1.56859005e+15]
# iteration: 82
# best value of objective function so far: 1.520892118962812
# best candidate: [-4.75556859e-01 -6.80626916e+06  1.56859005e+15]
# iteration: 83
# best value of objective function so far: 1.520892118962812
# best candidate: [-4.75556859e-01 -6.80626916e+06  1.56859005e+15]
# iteration: 84
# best value of objective function so far: 1.520892118962812
# best candidate: [-4.75556859e-01 -6.80626916e+06  1.56859005e+15]
# iteration: 85
# best value of objective function so far: 1.520892118962812
# best candidate: [-4.75556859e-01 -6.80626916e+06  1.56859005e+15]
# iteration: 86
# best value of objective function so far: 1.4987601777556676
# best candidate: [-4.75526466e-01 -6.74929429e+06  1.56859005e+15]
# iteration: 87
# best value of objective function so far: 1.4987601777556676
# best candidate: [-4.75526466e-01 -6.74929429e+06  1.56859005e+15]
# iteration: 88
# best value of objective function so far: 1.4987601777556676
# best candidate: [-4.75526466e-01 -6.74929429e+06  1.56859005e+15]
# iteration: 89
# best value of objective function so far: 1.4987601777556676
# best candidate: [-4.75526466e-01 -6.74929429e+06  1.56859005e+15]
# iteration: 90
# best value of objective function so far: 1.4987601777556676
# best candidate: [-4.75526466e-01 -6.74929429e+06  1.56859005e+15]
# iteration: 91
# best value of objective function so far: 1.4976600184791806
# best candidate: [-4.75511145e-01 -6.73147769e+06  1.56859005e+15]
# iteration: 92
# best value of objective function so far: 1.4927148419021314
# best candidate: [-4.75532905e-01 -6.78110919e+06  1.56859005e+15]
# iteration: 93
# best value of objective function so far: 1.4902517213008515
# best candidate: [-4.75502260e-01 -6.73430149e+06  1.56859005e+15]
# iteration: 94
# best value of objective function so far: 1.4759235258993597
# best candidate: [-4.75483605e-01 -6.74800608e+06  1.56859005e+15]
# iteration: 95
# best value of objective function so far: 1.4662017430695349
# best candidate: [-4.75492147e-01 -6.82083480e+06  1.56859005e+15]
# iteration: 96
# best value of objective function so far: 1.4662017430695349
# best candidate: [-4.75492147e-01 -6.82083480e+06  1.56859005e+15]
# iteration: 97
# best value of objective function so far: 1.4662017430695349
# best candidate: [-4.75492147e-01 -6.82083480e+06  1.56859005e+15]
# iteration: 98
# best value of objective function so far: 1.4662017430695349
# best candidate: [-4.75492147e-01 -6.82083480e+06  1.56859005e+15]
# iteration: 99
# best value of objective function so far: 1.4642033503483893
# best candidate: [-4.75470559e-01 -6.81590310e+06  1.56859005e+15]
# iteration: 100
# best value of objective function so far: 1.4642033503483893
# best candidate: [-4.75470559e-01 -6.81590310e+06  1.56859005e+15]
# [-4.75470559e-01 -6.81590310e+06  1.56859005e+15]
# 1.4642033503483893
# Maximum number of iterations exceeded.
# iterations: 100
# function evaluations: 190
